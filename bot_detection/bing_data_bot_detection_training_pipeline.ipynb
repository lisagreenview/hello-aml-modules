# %% [markdown]
# # Bing Data Bot Detection Training Pipeline
#
# ## Prerequisite
#
# - Create windows compute, see https://eemo.visualstudio.com/TEE/_git/TEEGit?path=%2FOffline%2FSmartCompose%2Faml%2FSetup_AML_Windows_Compute_Cluster.md&version=GBhaoz%2Fsmartcompose&_a=preview for instructions.
# - Manually install dependencies on created windows compute by
# ```
# pip install azureml-pipeline-wrapper[notebooks]==0.1.0.16323496 azureml-sdk==0.1.0.16323496 --extra-index-url https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/16323496
# pip install pandas pyarrow
# ```

# %%
import os
from azureml.core import Workspace
from azureml.core.compute import AmlCompute, ComputeTarget
from azureml.pipeline.wrapper import Module, Pipeline, dsl

# %% [markdown]
# ## Configure workspace and compute

# %%
# configure workspace information here.
workspace = Workspace.get(
    name='heta-EUS',
    subscription_id='e9b2ec51-5c94-4fa8-809a-dc1e695e4896',
    resource_group='thy-experiment'
)
print(workspace.name, workspace.resource_group, workspace.location, workspace.subscription_id, sep = '\n')
# Out:
# WARNING - Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.
# heta-EUS
# thy-experiment
# eastus
# e9b2ec51-5c94-4fa8-809a-dc1e695e4896

# %%
# specify windows compute name.
windows_compute_target = "windows-cluster"
# specify aml compute name.
aml_compute_target = 'aml-compute'
try:
    windows_compute = AmlCompute(workspace, windows_compute_target)
    print("Found existing windows compute target: {}".format(windows_compute_target))
except:
    print("Need to create a windows compute")

try:
    aml_compute = AmlCompute(workspace, aml_compute_target)
    print("Found existing aml compute target: {}".format(aml_compute_target))
except:
    print("Creating new aml compute target: {}".format(aml_compute_target))  
    provisioning_config = AmlCompute.provisioning_configuration(vm_size = "STANDARD_D2_V2",
                                                                min_nodes = 0, 
                                                                max_nodes = 4)    
    aml_compute = ComputeTarget.create(workspace, aml_compute_target, provisioning_config)
    aml_compute.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Found existing windows compute target: windows-cluster
# Found existing aml compute target: aml-compute

# %% [markdown]
# ## Prepare dataset

# %%
# prepare dataset.
data_folder = './data'
label_id_file_name = 'bing_data_label.tsv'
fea_id_file_name = 'bing_data_feature.tsv'
target_path = 'bot-detection'
label_id_dataset_name = 'bing-data-label-dataset'
fea_id_dataset_name = 'bing-data-feature-dataset'

# %%
# upload dataset
datastore = workspace.get_default_datastore()
datastore.upload_files(files = [f'{data_folder}/{label_id_file_name}'], target_path = target_path, overwrite = True,show_progress = True)
datastore.upload_files(files = [f'{data_folder}/{fea_id_file_name}'], target_path = target_path, overwrite = True,show_progress = True)
# Out:
# Uploading an estimated of 1 files
# Uploading ./data/bing_data_label.tsv
# Uploaded ./data/bing_data_label.tsv, 1 files out of an estimated total of 1
# Uploaded 1 files
# Uploading an estimated of 1 files
# Uploading ./data/bing_data_feature.tsv
# Uploaded ./data/bing_data_feature.tsv, 1 files out of an estimated total of 1
# Uploaded 1 files
# $AZUREML_DATAREFERENCE_98b6c870873f452190175926ff63c1f0

# %%
# register dataset
from azureml.core.dataset import Dataset

label_id_dataset = Dataset.File.from_files((datastore, f'{target_path}/{label_id_file_name}'))
label_id_dataset = label_id_dataset.register(workspace, name=label_id_dataset_name, create_new_version=True)

fea_id_dataset = Dataset.File.from_files((datastore, f'{target_path}/{fea_id_file_name}'))
fea_id_dataset = fea_id_dataset.register(workspace, name=fea_id_dataset_name, create_new_version=True)

# %% [markdown]
# ## Load modules

# %%
# load built-in modules
remove_dup_rows_func = Module.load(workspace, namespace='azureml', name='Remove Duplicate Rows')
join_data_func = Module.load(workspace, namespace='azureml', name='Join Data')
norm_data_func = Module.load(workspace, namespace='azureml', name='Normalize Data')
split_data_func = Module.load(workspace, namespace='azureml', name='Split Data')

# %%
# load local modules
module_folder = r'./modules'
yaml_file_name = 'entry.spec.yaml'
tlc_train_module = Module.from_yaml(workspace, yaml_file=f'{module_folder}/tlc_train/{yaml_file_name}')
tlc_test_module = Module.from_yaml(workspace, yaml_file=f'{module_folder}/tlc_test/{yaml_file_name}')

# %% [markdown]
# ## Set up a pipeline

# %%
# define pipeline
@dsl.pipeline(name='bot detection', description='bot detection', default_compute_target='aml-compute')
def generated_pipeline():
    remove_dup_id_in_label = remove_dup_rows_func(
        dataset=label_id_dataset,
        key_column_selection_filter_expression='{\"isFilter\":true,\"rules\":[{\"exclude\":false,\"ruleType\":\"ColumnNames\",\"columns\":[\"Id\"]}]}',
        retain_first_duplicate_row=True
    )
    
    remove_dup_id_in_fea = remove_dup_rows_func(
        dataset=fea_id_dataset,
        key_column_selection_filter_expression='{\"isFilter\":true,\"rules\":[{\"exclude\":false,\"ruleType\":\"ColumnNames\",\"columns\":[\"Id\"]}]}',
        retain_first_duplicate_row=True
    )
    
    join = join_data_func(
        dataset1=remove_dup_id_in_label.outputs.results_dataset,
        dataset2=remove_dup_id_in_fea.outputs.results_dataset,
        comma_separated_case_sensitive_names_of_join_key_columns_for_l='{\"isFilter\":true,\"rules\":[{\"exclude\":false,\"ruleType\":\"ColumnNames\",\"columns\":[\"Id\"]}]}',
        comma_separated_case_sensitive_names_of_join_key_columns_for_r='{\"isFilter\":true,\"rules\":[{\"exclude\":false,\"ruleType\":\"ColumnNames\",\"columns\":[\"Id\"]}]}',
        match_case=True,
        join_type="Inner Join",
        keep_right_key_columns_in_joined_table=False
    )
    
    norm = norm_data_func(
        dataset=join.outputs.results_dataset,
        transformation_method="MinMax",
        use_0_for_constant_columns_when_checked=True,
        columns_to_transform='{\"isFilter\":true,\"rules\":[{\"exclude\":false,\"ruleType\":\"ColumnNames\",\"columns\":[\"BD_NormalizedImpressionWithFDAuthUserCount\"]}]}'
    )
    
    split = split_data_func(
        dataset=norm.outputs.transformed_dataset,
        splitting_mode="Split Rows",
        fraction_of_rows_in_the_first_output_dataset=0.9,
        randomized_split=True,
        random_seed=0,
        stratified_split="False",
        stratification_key_column='{\"isFilter\":true,\"rules\":[{\"exclude\":false,\"ruleType\":\"ColumnNames\",\"columns\":[\"Label\"]}]}'
    )
    
    train = tlc_train_module(
        training_data=split.outputs.results_dataset1,
        predictor="FastRankClassification{nl=60 mil=100 iter=100 lr=0.1}",
        instances_reader="StreamingInstances",
        instances_settings="{header+ label=0 name=1}",
        cache_instances_in_memory="+",
        random_seed=123,
        use_threads="+",
        proportion_of_train_data_to_use=1,
        print_model_summary="+"
    )
    train.runsettings.configure(target=windows_compute_target)
    
    test = tlc_test_module(
        trained_model=train.outputs.trained_model,
        test_data=split.outputs.results_dataset2,
        instances_reader="StreamingInstances",
        instances_settings="{header+ label=0 name=1}",
        cache_instances_in_memory="+",
        random_seed=123,
        use_threads="+",
        proportion_of_train_data_to_use=1,
        print_model_summary="+"
    )
    test.runsettings.configure(target=windows_compute_target)

# %%
# create a pipeline
pipeline = generated_pipeline()

# %%
# validate pipeline and visualize the graph
pipeline.validate()
# Out:
# windows-cluster not found in workspace, assume this is an AmlCompute
# windows-cluster not found in workspace, assume this is an AmlCompute
# SupportDetectView()
#         <style>
#         #container_id_7d31021e-86aa-4570-9a79-e0dc6a7027a9 svg.react-dag-editor-svg-container {
#             height: 800px;
#         }
#         </style>
#         <div id="container_id_7d31021e-86aa-4570-9a79-e0dc6a7027a9"></div>
#         <script>
#             window.render_container_id="container_id_7d31021e-86aa-4570-9a79-e0dc6a7027a9";
#             window.graph_json={"pipeline": {"name": "bot detection", "data_references": {"bing-data-label-dataset": {"dataset_id": "0f47ae86-2550-43c6-a57c-c5474f38ab1d"}, "bing-data-feature-dataset": {"dataset_id": "5d19434b-834c-4f3b-ba4b-3c48844469f6"}}, "steps": {"a4d524b2-687c-4faa-af6e-ec7bf2c6bd75": {"inputs": {"Dataset": {"source": "bing-data-label-dataset"}}, "outputs": {"Results_dataset": {"destination": "a4d524b2-687c-4faa-af6e-ec7bf2c6bd75_Results_dataset"}}, "module": {"id": "4ae6c832-f2eb-588f-a6a3-4af9dee9494b", "version": "0.0.124.33"}, "validate": {"error": [], "module_id": "4ae6c832-f2eb-588f-a6a3-4af9dee9494b", "namespace": "azureml", "module_name": "Remove Duplicate Rows", "module_version": "0.0.124.33"}}, "2e19dbab-90ad-421f-ad0b-0e7d6a4e11ce": {"inputs": {"Dataset": {"source": "bing-data-feature-dataset"}}, "outputs": {"Results_dataset": {"destination": "2e19dbab-90ad-421f-ad0b-0e7d6a4e11ce_Results_dataset"}}, "module": {"id": "4ae6c832-f2eb-588f-a6a3-4af9dee9494b", "version": "0.0.124.33"}, "validate": {"error": [], "module_id": "4ae6c832-f2eb-588f-a6a3-4af9dee9494b", "namespace": "azureml", "module_name": "Remove Duplicate Rows", "module_version": "0.0.124.33"}}, "cf8d4945-6ff1-4db8-a707-508004183849": {"inputs": {"Dataset2": {"source": "2e19dbab-90ad-421f-ad0b-0e7d6a4e11ce_Results_dataset"}, "Dataset1": {"source": "a4d524b2-687c-4faa-af6e-ec7bf2c6bd75_Results_dataset"}}, "outputs": {"Results_dataset": {"destination": "cf8d4945-6ff1-4db8-a707-508004183849_Results_dataset"}}, "module": {"id": "471d2aaa-ec1d-5f73-b21d-dea50a303125", "version": "0.0.124.33"}, "validate": {"error": [], "module_id": "471d2aaa-ec1d-5f73-b21d-dea50a303125", "namespace": "azureml", "module_name": "Join Data", "module_version": "0.0.124.33"}}, "be662941-197d-4ad1-bd2f-7d3e0bbd0c02": {"inputs": {"Dataset": {"source": "cf8d4945-6ff1-4db8-a707-508004183849_Results_dataset"}}, "outputs": {"Transformed_dataset": {"destination": "be662941-197d-4ad1-bd2f-7d3e0bbd0c02_Transformed_dataset"}, "Transformation_function": {"destination": "be662941-197d-4ad1-bd2f-7d3e0bbd0c02_Transformation_function"}}, "module": {"id": "8b3e48ac-f072-5991-b449-e7e0c89dfa2d", "version": "0.0.124.33"}, "validate": {"error": [], "module_id": "8b3e48ac-f072-5991-b449-e7e0c89dfa2d", "namespace": "azureml", "module_name": "Normalize Data", "module_version": "0.0.124.33"}}, "63ee9bdc-97e9-4193-a0fe-0a20677d475c": {"inputs": {"Dataset": {"source": "be662941-197d-4ad1-bd2f-7d3e0bbd0c02_Transformed_dataset"}}, "outputs": {"Results_dataset1": {"destination": "63ee9bdc-97e9-4193-a0fe-0a20677d475c_Results_dataset1"}, "Results_dataset2": {"destination": "63ee9bdc-97e9-4193-a0fe-0a20677d475c_Results_dataset2"}}, "module": {"id": "fa76b4f0-d6e3-517f-9dc3-a16d6e02312a", "version": "0.0.124.33"}, "validate": {"error": [], "module_id": "fa76b4f0-d6e3-517f-9dc3-a16d6e02312a", "namespace": "azureml", "module_name": "Split Data", "module_version": "0.0.124.33"}}, "954827cd-8c55-4a7e-b0f3-41884570170a": {"inputs": {"Training_Data": {"source": "63ee9bdc-97e9-4193-a0fe-0a20677d475c_Results_dataset1"}}, "outputs": {"Trained_Model": {"destination": "954827cd-8c55-4a7e-b0f3-41884570170a_Trained_Model"}, "Trained_Model_Text": {"destination": "954827cd-8c55-4a7e-b0f3-41884570170a_Trained_Model_Text"}, "Trained_Model_Summary": {"destination": "954827cd-8c55-4a7e-b0f3-41884570170a_Trained_Model_Summary"}, "Trained_Model_Ini_File": {"destination": "954827cd-8c55-4a7e-b0f3-41884570170a_Trained_Model_Ini_File"}}, "module": {"id": "75037e40-6402-4797-a6f4-75d22eb24da0", "version": "0.0.1"}, "validate": {"error": [], "module_id": "75037e40-6402-4797-a6f4-75d22eb24da0", "namespace": "heta-EUS", "module_name": "TLC: Train", "module_version": "0.0.1"}}, "cf03065d-a536-4ef5-a56a-c450a8b4e501": {"inputs": {"Test_Data": {"source": "63ee9bdc-97e9-4193-a0fe-0a20677d475c_Results_dataset2"}, "Trained_Model": {"source": "954827cd-8c55-4a7e-b0f3-41884570170a_Trained_Model"}}, "outputs": {"Per_Instance_Pred ...
# {'result': 'validation passed', 'errors': []}

# %%
# submit a pipeline run
pipeline.submit(experiment_name='bing_data_bot_detection').wait_for_completion()
# Out:
# windows-cluster not found in workspace, assume this is an AmlCompute
# windows-cluster not found in workspace, assume this is an AmlCompute
# Submitted PipelineRun e64b98e7-87cd-419b-b9f8-b03bb73b7c8e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bing_data_bot_detection/runs/e64b98e7-87cd-419b-b9f8-b03bb73b7c8e?wsid=/subscriptions/e9b2ec51-5c94-4fa8-809a-dc1e695e4896/resourcegroups/thy-experiment/workspaces/heta-EUS
# PipelineRunId: e64b98e7-87cd-419b-b9f8-b03bb73b7c8e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bing_data_bot_detection/runs/e64b98e7-87cd-419b-b9f8-b03bb73b7c8e?wsid=/subscriptions/e9b2ec51-5c94-4fa8-809a-dc1e695e4896/resourcegroups/thy-experiment/workspaces/heta-EUS
# PipelineRun Status: Running
#
#
# StepRunId: 4202dc95-69a7-4c3a-afcf-a9e5e6887933
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bing_data_bot_detection/runs/4202dc95-69a7-4c3a-afcf-a9e5e6887933?wsid=/subscriptions/e9b2ec51-5c94-4fa8-809a-dc1e695e4896/resourcegroups/thy-experiment/workspaces/heta-EUS
# StepRun( azureml://Remove Duplicate Rows ) Status: NotStarted
# StepRun( azureml://Remove Duplicate Rows ) Status: Queued
# StepRun( azureml://Remove Duplicate Rows ) Status: Running
#
# Streaming azureml-logs/65_job_prep-tvmps_a56482c300b240509ada69f6cfb808feb28e51b61dba1e1dc21739eef54f5503_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-06-25T11:28:24.737108
# Starting job preparation. Current time:2020-06-25T11:28:25.560550
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 15db5008-6c13-4636-9e88-9dc17f6633b0
# Starting the daemon thread to refresh tokens in background for process with pid = 49
# Starting project file download.
# Finished project file download.
# downloadDataStore - Download from datastores if requested.
# Entering context manager injector. Current time:2020-06-25T11:28:27.520413
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# Entering context manager injector. Current time:2020-06-25T11:28:30.463178
# Initialize DatasetContextManager.
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7')).
# Starting the daemon thread to refresh tokens in background for process with pid = 106
# Set Dataset Dataset's target path to /tmp/tmpg3glcf3o
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.6.0.post1 azureml-dataprep==1.6.3
# Processing 'Dataset'
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'bot-detection/bing_data_feature.tsv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "c23c7999-fab0-4e11-b35a-454bebda780b",
#     "name": "bing-data-feature-dataset",
#     "version": 1,
#     "workspace": "Workspace.create(name='heta-EUS', subscription_id='e9b2ec51-5c94-4fa8-809a-dc1e695e4896', resource_group='thy-experiment')"
#   }
# }
# Mounting Dataset to /tmp/tmpg3glcf3o
# Mounted Dataset to /tmp/tmpg3glcf3o
# Exit __enter__ of DatasetContextManager
# Entering Run History Context Manager.
# Preparing to call script [ urldecode_invoker.py ] with arguments: ['python', '-m', 'azureml.studio.modulehost.module_invoker', '--module-name=azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows', '--dataset=$Dataset', '--results-dataset=/mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/mounts/workspaceblobstore/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/Results_dataset', '--key-column-selection-filter-expression=%7b%5c%22isFilter%5c%22%3atrue%2c%5c%22rules%5c%22%3a%5b%7b%5c%22exclude%5c%22%3afalse%2c%5c%22ruleType%5c%22%3a%5c%22ColumnNames%5c%22%2c%5c%22columns%5c%22%3a%5b%5c%22Id%5c%22%5d%7d%5d%7d', '--retain-first-duplicate-row=True']
# After variable expansion, calling script [ urldecode_invoker.py ] with arguments: ['python', '-m', 'azureml.studio.modulehost.module_invoker', '--module-name=azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows', '--dataset=/tmp/tmpg3glcf3o/bing_data_feature.tsv', '--results-dataset=/mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/mounts/workspaceblobstore/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/Results_dataset', '--key-column-selection-filter-expression=%7b%5c%22isFilter%5c%22%3atrue%2c%5c%22rules%5c%22%3a%5b%7b%5c%22exclude%5c%22%3afalse%2c%5c%22ruleType%5c%22%3a%5c%22ColumnNames%5c%22%2c%5c%22columns%5c%22%3a%5b%5c%22Id%5c%22%5d%7d%5d%7d', '--retain-first-duplicate-row=True']
#
# Session_id = 16d5a6dd-8bfa-4f14-a77a-e9df7d53bf52
# Invoking module by urldecode_invoker 0.0.8.
#
# Module type: official module.
#
# Using runpy to invoke module 'azureml.studio.modulehost.module_invoker'.
#
# 2020-06-25 11:28:46,746 studio.modulehost    INFO       Reset logging level to DEBUG
# 2020-06-25 11:28:46,746 studio.modulehost    INFO       Load pyarrow.parquet explicitly: <module 'pyarrow.parquet' from '/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages/pyarrow/parquet.py'>
# 2020-06-25 11:28:46,747 studio.core          INFO       execute_with_cli - Start:
# 2020-06-25 11:28:46,747 studio.modulehost    INFO       |   ALGHOST 0.0.124
# 2020-06-25 11:28:46,749 studio.modulehost    INFO       |   CLI arguments parsed: {'module_name': 'azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows', 'OutputPortsInternal': {'Results dataset': '/mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/mounts/workspaceblobstore/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/Results_dataset'}, 'InputPortsInternal': {'Dataset': '/tmp/tmpg3glcf3o/bing_data_feature.tsv'}, 'ModuleParameters': {'Key column selection filter expression': '{"isFilter":true,"rules":[{"exclude":false,"ruleType":"ColumnNames","columns":["Id"]}]}', 'Retain first duplicate row': 'True'}}
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7')).
# 2020-06-25 11:28:49,751 studio.modulehost    INFO       |   Invoking ModuleEntry(azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows; RemoveDuplicateRowsModule; run)
# 2020-06-25 11:28:49,751 studio.core          DEBUG      |   Input Ports:
# 2020-06-25 11:28:49,752 studio.core          DEBUG      |   |   Dataset = <azureml.studio.modulehost.cli_parser.CliInputValue object at 0x7f870b40f240>
# 2020-06-25 11:28:49,752 studio.core          DEBUG      |   Output Ports:
# 2020-06-25 11:28:49,752 studio.core          DEBUG      |   |   Results dataset = /mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/mounts/workspaceblobstore/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/Results_dataset
# 2020-06-25 11:28:49,752 studio.core          DEBUG      |   Parameters:
# 2020-06-25 11:28:49,752 studio.core          DEBUG      |   |   Key column selection filter expression = {"isFilter":true,"rules":[{"exclude":false,"ruleType":"ColumnNames","columns":["Id"]}]}
# 2020-06-25 11:28:49,752 studio.core          DEBUG      |   |   Retain first duplicate row = True
# 2020-06-25 11:28:49,753 studio.core          DEBUG      |   Environment Variables:
# 2020-06-25 11:28:49,753 studio.core          DEBUG      |   |   AZUREML_DATAREFERENCE_Results_dataset = /mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/mounts/workspaceblobstore/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/Results_dataset
# 2020-06-25 11:28:49,753 studio.core          DEBUG      |   |   AZUREML_DATAREFERENCE_Dataset = /tmp/tmpg3glcf3o/bing_data_feature.tsv
# 2020-06-25 11:28:49,753 studio.core          INFO       |   Reflect input ports and parameters - Start:
# 2020-06-25 11:28:49,753 studio.core          INFO       |   |   Handle input port "Dataset" - Start:
# 2020-06-25 11:28:49,753 studio.core          INFO       |   |   |   Mount/Download dataset to '/tmp/tmpg3glcf3o' - Start:
# 2020-06-25 11:28:49,753 studio.modulehost    DEBUG      |   |   |   |   Content of directory /tmp/tmpg3glcf3o:
# 2020-06-25 11:28:49,877 studio.modulehost    DEBUG      |   |   |   |   |   bing_data_feature.tsv
# 2020-06-25 11:28:49,877 studio.core          INFO       |   |   |   Mount/Download dataset to '/tmp/tmpg3glcf3o' - End with 0.1237s elapsed.
# 2020-06-25 11:28:49,886 studio.modulehost    INFO       |   |   |   Meta file not found, fallback to legacy handler.
# 2020-06-25 11:28:49,886 studio.modulehost    INFO       |   |   |   Folder: '/tmp/tmpg3glcf3o'
# 2020-06-25 11:28:49,886 studio.modulehost    INFO       |   |   |   File Name: 'bing_data_feature.tsv'
# 2020-06-25 11:28:49,886 studio.modulehost    INFO       |   |   |   Data type: 'GenericTSV'
# 2020-06-25 11:28:49,886 studio.core          INFO       |   |   |   Read from 'bing_data_feature.tsv' via DataTableTsvHandler - Start:
# 2020-06-25 11:28:49,886 studio.modulehost    INFO       |   |   |   |   Read DataTable from TSV with header
# 2020-06-25 11:28:49,886 studio.core          INFO       |   |   |   |   DataTableCsvReader.read - Start:
# 2020-06-25 11:28:49,886 studio.core          INFO       |   |   |   |   |   DataTableCsvReader.read_as_data_frame - Start:
# 2020-06-25 11:28:49,887 studio.core          INFO       |   |   |   |   |   |   DataFrame read csv/tsv in chunks with chunk size:50000 - Start:
# 2020-06-25 11:28:50,206 studio.core          INFO       |   |   |   |   |   |   DataFrame read csv/tsv in chunks with chunk size:50000 - End with 0.3193s elapsed.
# 2020-06-25 11:28:50,206 studio.core          INFO       |   |   |   |   |   |   DataTableCsvReader._validate_dtypes_in_chunks - Start:
# 2020-06-25 11:28:50,206 studio.core          INFO       |   |   |   |   |   |   DataTableCsvReader._validate_dtypes_in_chunks - End with 0.0000s elapsed.
# 2020-06-25 11:28:50,206 studio.core          INFO       |   |   |   |   |   |   Dataframe chunks concat - Start:
# 2020-06-25 11:28:50,209 studio.core          INFO       |   |   |   |   |   |   Dataframe chunks concat - End with 0.0023s elapsed.
# 2020-06-25 11:28:50,209 studio.core          INFO       |   |   |   |   |   DataTableCsvReader.read_as_data_frame - End with 0.3224s elapsed.
# 2020-06-25 11:28:50,209 studio.core          INFO       |   |   |   |   |   DataTable Construction - Start:
# 2020-06-25 11:28:50,242 studio.core          INFO       |   |   |   |   |   DataTable Construction - End with 0.0323s elapsed.
# 2020-06-25 11:28:50,242 studio.core          INFO       |   |   |   |   DataTableCsvReader.read - End with 0.3553s elapsed.
# 2020-06-25 11:28:50,242 studio.core          INFO       |   |   |   Read from 'bing_data_feature.tsv' via DataTableTsvHandler - End with 0.3556s elapsed.
# 2020-06-25 11:28:50,242 studio.core          INFO       |   |   Handle input port "Dataset" - End with 0.4889s elapsed.
# 2020-06-25 11:28:50,242 studio.modulehost    INFO       |   |   Parse ColumnSelection parameter
# 2020-06-25 11:28:50,242 studio.modulehost    INFO       |   |   Parse bool parameter
# 2020-06-25 11:28:50,242 studio.core          INFO       |   Reflect input ports and parameters - End with 0.4895s elapsed.
# 2020-06-25 11:28:50,242 studio.core          INFO       |   RemoveDuplicateRowsModule.run - Start:
# 2020-06-25 11:28:50,243 studio.core          DEBUG      |   |   kwargs:
# 2020-06-25 11:28:50,243 studio.core          DEBUG      |   |   |   data_table = <azureml.studio.common.datatable.data_table.DataTable object at 0x7f8741ba6dd8>
# 2020-06-25 11:28:50,243 studio.core          DEBUG      |   |   |   key_columns = <azureml.studio.common.datatable.data_table.DataTableColumnSelection object at 0x7f8741bc0f98>
# 2020-06-25 11:28:50,243 studio.core          DEBUG      |   |   |   take_first_otherwise_last = True
# 2020-06-25 11:28:50,243 studio.core          DEBUG      |   |   validated_args:
# 2020-06-25 11:28:50,243 studio.core          DEBUG      |   |   |   data_table = <azureml.studio.common.datatable.data_table.DataTable object at 0x7f8741ba6dd8>
# 2020-06-25 11:28:50,243 studio.core          DEBUG      |   |   |   key_columns = <azureml.studio.common.datatable.data_table.DataTableColumnSelection object at 0x7f8741bc0f98>
# 2020-06-25 11:28:50,243 studio.core          DEBUG      |   |   |   take_first_otherwise_last = True
# 2020-06-25 11:28:50,243 studio.core          INFO       |   |   Remove duplicated rows - Start:
# 2020-06-25 11:28:50,251 studio.core          INFO       |   |   Remove duplicated rows - End with 0.0070s elapsed.
# 2020-06-25 11:28:50,276 studio.core          DEBUG      |   |   return:
# 2020-06-25 11:28:50,276 studio.core          DEBUG      |   |   |   [0] = <DataTable (793 Rows, 219 Cols) at 0x00007F870B3AEC88>
# 2020-06-25 11:28:50,276 studio.core          INFO       |   RemoveDuplicateRowsModule.run - End with 0.0335s elapsed.
# 2020-06-25 11:28:50,276 studio.core          INFO       |   ModuleReflector._handle_output_ports - Start:
# 2020-06-25 11:28:50,276 studio.core          INFO       |   |   Handle output port "Results dataset" - Start:
# 2020-06-25 11:28:50,276 studio.modulehost    INFO       |   |   |   Data type: Dataset
# 2020-06-25 11:28:50,276 studio.modulehost    INFO       |   |   |   Create directory: '/mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/mounts/workspaceblobstore/azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/Results_dataset'
# 2020-06-25 11:28:50,308 studio.core          INFO       |   |   |   Create file 'data.dataset.parquet' via DataTableDatasetHandler - Start:
# 2020-06-25 11:28:50,308 studio.modulehost    INFO       |   |   |   |   Write DataTable into Dataset
# 2020-06-25 11:28:50,308 studio.core          INFO       |   |   |   |   Write pickle file 'data.dataset' - Start:
# 2020-06-25 11:28:50,330 studio.core          INFO       |   |   |   |   Write pickle file 'data.dataset' - End with 0.0218s elapsed.
# 2020-06-25 11:28:50,331 studio.core          INFO       |   |   |   |   Write to parquet file 'data.dataset.parquet'. Rows: 793, Columns: 219. - Start:
# 2020-06-25 11:28:50,399 studio.core          INFO       |   |   |   |   Write to parquet file 'data.dataset.parquet'. Rows: 793, Columns: 219. - End with 0.0684s elapsed.
# 2020-06-25 11:28:50,399 studio.core          INFO       |   |   |   Create file 'data.dataset.parquet' via DataTableDatasetHandler - End with 0.0910s elapsed.
# 2020-06-25 11:28:50,400 studio.core          INFO       |   |   |   Create sidecar file 'data.schema' - Start:
# 2020-06-25 11:28:50,428 studio.core          INFO       |   |   |   Create sidecar file 'data.schema' - End with 0.0284s elapsed.
# 2020-06-25 11:28:50,428 studio.core          INFO       |   |   |   Create sidecar file 'data.visualization' - Start:
# 2020-06-25 11:28:51,002 studio.core          INFO       |   |   |   Create sidecar file 'data.visualization' - End with 0.5733s elapsed.
# 2020-06-25 11:28:51,002 studio.core          INFO       |   |   |   Create sidecar file 'data.metadata' - Start:
# 2020-06-25 11:28:51,071 studio.core          INFO       |   |   |   Create sidecar file 'data.metadata' - End with 0.0685s elapsed.
# 2020-06-25 11:28:51,232 studio.common        INFO       |   |   |   Writing meta successfully, datatype=DataTypes.DATASET
# 2020-06-25 11:28:51,232 studio.core          INFO       |   |   |   Create data type file 'data_type.json' - Start:
# 2020-06-25 11:28:51,301 studio.core          INFO       |   |   |   Create data type file 'data_type.json' - End with 0.0687s elapsed.
# 2020-06-25 11:28:51,301 studio.core          INFO       |   |   Handle output port "Results dataset" - End with 1.0249s elapsed.
# 2020-06-25 11:28:51,301 studio.core          INFO       |   ModuleReflector._handle_output_ports - End with 1.0251s elapsed.
# 2020-06-25 11:28:51,301 studio.core          INFO       |   ModuleStatistics.save_to_azureml - Start:
# 2020-06-25 11:28:51,575 studio.core          INFO       |   ModuleStatistics.save_to_azureml - End with 0.2735s elapsed.
# 2020-06-25 11:28:51,576 studio.core          INFO       execute_with_cli - End with 4.8291s elapsed.
# Starting the daemon thread to refresh tokens in background for process with pid = 106
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.21851181983947754 seconds
# Enter __exit__ of DatasetContextManager
# Unmounting /tmp/tmpg3glcf3o.
# Finishing unmounting /tmp/tmpg3glcf3o.
# Exit __exit__ of DatasetContextManager
# StepRun(azureml://Remove Duplicate Rows) Execution Summary
# ===========================================================
# StepRun( azureml://Remove Duplicate Rows ) Status: Finalizing
# {'runId': '4202dc95-69a7-4c3a-afcf-a9e5e6887933', 'target': 'aml-compute', 'status': 'Finalizing', 'startTimeUtc': '2020-06-25T11:28:22.228473Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '15db5008-6c13-4636-9e88-9dc17f6633b0', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '4ae6c832-f2eb-588f-a6a3-4af9dee9494b', 'azureml.pipelinerunid': 'e64b98e7-87cd-419b-b9f8-b03bb73b7c8e', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'c23c7999-fab0-4e11-b35a-454bebda780b'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Dataset', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'urldecode_invoker.py', 'useAbsolutePath': False, 'arguments': ['python', '-m', 'azureml.studio.modulehost.module_invoker', '--module-name=azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows', '--dataset=$AZUREML_DATAREFERENCE_Dataset', '--results-dataset=$AZUREML_DATAREFERENCE_Results_dataset', '--key-column-selection-filter-expression=%7b%5c%22isFilter%5c%22%3atrue%2c%5c%22rules%5c%22%3a%5b%7b%5c%22exclude%5c%22%3afalse%2c%5c%22ruleType%5c%22%3a%5c%22ColumnNames%5c%22%2c%5c%22columns%5c%22%3a%5b%5c%22Id%5c%22%5d%7d%5d%7d', '--retain-first-duplicate-row=True'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-compute', 'dataReferences': {'Results_dataset': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/4202dc95-69a7-4c3a-afcf-a9e5e6887933/Results_dataset', 'pathOnCompute': None, 'overwrite': True}}, 'data': {'Dataset': {'dataLocation': {'dataset': {'id': 'c23c7999-fab0-4e11-b35a-454bebda780b', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Dataset', 'pathOnCompute': None, 'overwrite': True}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment bing_data_bot_detection Environment', 'version': 'Autosave_2020-06-25T11:28:06Z_bd2fba2f', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['conda-forge'], 'dependencies': ['python=3.6.8', 'scikit-surprise=1.0.6', {'pip': ['azureml-designer-classic-modules==0.0.124', 'https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm', 'spacy==2.1.7']}], 'name': 'azureml_a62e52e5220d24c0f3e291434f99287c'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'AZUREML_PARAMETER_Key_column_selection_filter_expression': '{"isFilter":true,"rules":[{"exclude":false,"ruleType":"ColumnNames","columns":["Id"]}]}', 'AZUREML_PARAMETER_Retain_first_duplicate_row': 'True'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 0, 'parameterServerCount': 0}, 'mpi': {'processCountPerNode': 0}, 'hdi': {'yarnDeployMode': 'None'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '1g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}, 'cmAksCompute': {'c ...
# StepRunId: 2317315d-4532-46b6-b989-de9707209a3a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bing_data_bot_detection/runs/2317315d-4532-46b6-b989-de9707209a3a?wsid=/subscriptions/e9b2ec51-5c94-4fa8-809a-dc1e695e4896/resourcegroups/thy-experiment/workspaces/heta-EUS
# StepRun( azureml://Remove Duplicate Rows ) Status: Queued
# StepRun( azureml://Remove Duplicate Rows ) Status: Running
#
# Streaming azureml-logs/65_job_prep-tvmps_a56482c300b240509ada69f6cfb808feb28e51b61dba1e1dc21739eef54f5503_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-06-25T11:29:12.180024
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# Entering context manager injector. Current time:2020-06-25T11:29:17.655419
# Initialize DatasetContextManager.
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7')).
# Starting the daemon thread to refresh tokens in background for process with pid = 103
# Set Dataset Dataset's target path to /tmp/tmpfhquwfi1
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.6.0.post1 azureml-dataprep==1.6.3
# Processing 'Dataset'
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'bot-detection/bing_data_label.tsv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "afa83078-472d-434f-9834-6cd8f8f35363",
#     "name": "bing-data-label-dataset",
#     "version": 1,
#     "workspace": "Workspace.create(name='heta-EUS', subscription_id='e9b2ec51-5c94-4fa8-809a-dc1e695e4896', resource_group='thy-experiment')"
#   }
# }
# Mounting Dataset to /tmp/tmpfhquwfi1
# Mounted Dataset to /tmp/tmpfhquwfi1
# Exit __enter__ of DatasetContextManager
# Entering Run History Context Manager.
# Preparing to call script [ urldecode_invoker.py ] with arguments: ['python', '-m', 'azureml.studio.modulehost.module_invoker', '--module-name=azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows', '--dataset=$Dataset', '--results-dataset=/mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/2317315d-4532-46b6-b989-de9707209a3a/mounts/workspaceblobstore/azureml/2317315d-4532-46b6-b989-de9707209a3a/Results_dataset', '--key-column-selection-filter-expression=%7b%5c%22isFilter%5c%22%3atrue%2c%5c%22rules%5c%22%3a%5b%7b%5c%22exclude%5c%22%3afalse%2c%5c%22ruleType%5c%22%3a%5c%22ColumnNames%5c%22%2c%5c%22columns%5c%22%3a%5b%5c%22Id%5c%22%5d%7d%5d%7d', '--retain-first-duplicate-row=True']
# After variable expansion, calling script [ urldecode_invoker.py ] with arguments: ['python', '-m', 'azureml.studio.modulehost.module_invoker', '--module-name=azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows', '--dataset=/tmp/tmpfhquwfi1/bing_data_label.tsv', '--results-dataset=/mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/2317315d-4532-46b6-b989-de9707209a3a/mounts/workspaceblobstore/azureml/2317315d-4532-46b6-b989-de9707209a3a/Results_dataset', '--key-column-selection-filter-expression=%7b%5c%22isFilter%5c%22%3atrue%2c%5c%22rules%5c%22%3a%5b%7b%5c%22exclude%5c%22%3afalse%2c%5c%22ruleType%5c%22%3a%5c%22ColumnNames%5c%22%2c%5c%22columns%5c%22%3a%5b%5c%22Id%5c%22%5d%7d%5d%7d', '--retain-first-duplicate-row=True']
#
# Session_id = 7cf9159f-3d3f-43dc-a36d-3b3fbe9f83f0
# Invoking module by urldecode_invoker 0.0.8.
#
# Module type: official module.
#
# Using runpy to invoke module 'azureml.studio.modulehost.module_invoker'.
#
# 2020-06-25 11:29:32,031 studio.modulehost    INFO       Reset logging level to DEBUG
# 2020-06-25 11:29:32,031 studio.modulehost    INFO       Load pyarrow.parquet explicitly: <module 'pyarrow.parquet' from '/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages/pyarrow/parquet.py'>
# 2020-06-25 11:29:32,031 studio.core          INFO       execute_with_cli - Start:
# 2020-06-25 11:29:32,031 studio.modulehost    INFO       |   ALGHOST 0.0.124
# 2020-06-25 11:29:32,034 studio.modulehost    INFO       |   CLI arguments parsed: {'module_name': 'azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows', 'OutputPortsInternal': {'Results dataset': '/mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/2317315d-4532-46b6-b989-de9707209a3a/mounts/workspaceblobstore/azureml/2317315d-4532-46b6-b989-de9707209a3a/Results_dataset'}, 'InputPortsInternal': {'Dataset': '/tmp/tmpfhquwfi1/bing_data_label.tsv'}, 'ModuleParameters': {'Key column selection filter expression': '{"isFilter":true,"rules":[{"exclude":false,"ruleType":"ColumnNames","columns":["Id"]}]}', 'Retain first duplicate row': 'True'}}
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7')).
# 2020-06-25 11:29:35,663 studio.modulehost    INFO       |   Invoking ModuleEntry(azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows; RemoveDuplicateRowsModule; run)
# 2020-06-25 11:29:35,663 studio.core          DEBUG      |   Input Ports:
# 2020-06-25 11:29:35,663 studio.core          DEBUG      |   |   Dataset = <azureml.studio.modulehost.cli_parser.CliInputValue object at 0x7f98d53304e0>
# 2020-06-25 11:29:35,663 studio.core          DEBUG      |   Output Ports:
# 2020-06-25 11:29:35,663 studio.core          DEBUG      |   |   Results dataset = /mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/2317315d-4532-46b6-b989-de9707209a3a/mounts/workspaceblobstore/azureml/2317315d-4532-46b6-b989-de9707209a3a/Results_dataset
# 2020-06-25 11:29:35,663 studio.core          DEBUG      |   Parameters:
# 2020-06-25 11:29:35,663 studio.core          DEBUG      |   |   Key column selection filter expression = {"isFilter":true,"rules":[{"exclude":false,"ruleType":"ColumnNames","columns":["Id"]}]}
# 2020-06-25 11:29:35,663 studio.core          DEBUG      |   |   Retain first duplicate row = True
# 2020-06-25 11:29:35,664 studio.core          DEBUG      |   Environment Variables:
# 2020-06-25 11:29:35,664 studio.core          DEBUG      |   |   AZUREML_DATAREFERENCE_Results_dataset = /mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/2317315d-4532-46b6-b989-de9707209a3a/mounts/workspaceblobstore/azureml/2317315d-4532-46b6-b989-de9707209a3a/Results_dataset
# 2020-06-25 11:29:35,664 studio.core          DEBUG      |   |   AZUREML_DATAREFERENCE_Dataset = /tmp/tmpfhquwfi1/bing_data_label.tsv
# 2020-06-25 11:29:35,664 studio.core          INFO       |   Reflect input ports and parameters - Start:
# 2020-06-25 11:29:35,664 studio.core          INFO       |   |   Handle input port "Dataset" - Start:
# 2020-06-25 11:29:35,665 studio.core          INFO       |   |   |   Mount/Download dataset to '/tmp/tmpfhquwfi1' - Start:
# 2020-06-25 11:29:35,665 studio.modulehost    DEBUG      |   |   |   |   Content of directory /tmp/tmpfhquwfi1:
# 2020-06-25 11:29:35,776 studio.modulehost    DEBUG      |   |   |   |   |   bing_data_label.tsv
# 2020-06-25 11:29:35,776 studio.core          INFO       |   |   |   Mount/Download dataset to '/tmp/tmpfhquwfi1' - End with 0.1116s elapsed.
# 2020-06-25 11:29:35,785 studio.modulehost    INFO       |   |   |   Meta file not found, fallback to legacy handler.
# 2020-06-25 11:29:35,785 studio.modulehost    INFO       |   |   |   Folder: '/tmp/tmpfhquwfi1'
# 2020-06-25 11:29:35,786 studio.modulehost    INFO       |   |   |   File Name: 'bing_data_label.tsv'
# 2020-06-25 11:29:35,787 studio.modulehost    INFO       |   |   |   Data type: 'GenericTSV'
# 2020-06-25 11:29:35,788 studio.core          INFO       |   |   |   Read from 'bing_data_label.tsv' via DataTableTsvHandler - Start:
# 2020-06-25 11:29:35,788 studio.modulehost    INFO       |   |   |   |   Read DataTable from TSV with header
# 2020-06-25 11:29:35,789 studio.core          INFO       |   |   |   |   DataTableCsvReader.read - Start:
# 2020-06-25 11:29:35,789 studio.core          INFO       |   |   |   |   |   DataTableCsvReader.read_as_data_frame - Start:
# 2020-06-25 11:29:35,790 studio.core          INFO       |   |   |   |   |   |   DataFrame read csv/tsv in chunks with chunk size:50000 - Start:
# 2020-06-25 11:29:35,963 studio.core          INFO       |   |   |   |   |   |   DataFrame read csv/tsv in chunks with chunk size:50000 - End with 0.1723s elapsed.
# 2020-06-25 11:29:35,963 studio.core          INFO       |   |   |   |   |   |   DataTableCsvReader._validate_dtypes_in_chunks - Start:
# 2020-06-25 11:29:35,963 studio.core          INFO       |   |   |   |   |   |   DataTableCsvReader._validate_dtypes_in_chunks - End with 0.0000s elapsed.
# 2020-06-25 11:29:35,963 studio.core          INFO       |   |   |   |   |   |   Dataframe chunks concat - Start:
# 2020-06-25 11:29:35,964 studio.core          INFO       |   |   |   |   |   |   Dataframe chunks concat - End with 0.0004s elapsed.
# 2020-06-25 11:29:35,964 studio.core          INFO       |   |   |   |   |   DataTableCsvReader.read_as_data_frame - End with 0.1735s elapsed.
# 2020-06-25 11:29:35,964 studio.core          INFO       |   |   |   |   |   DataTable Construction - Start:
# 2020-06-25 11:29:35,967 studio.core          INFO       |   |   |   |   |   DataTable Construction - End with 0.0028s elapsed.
# 2020-06-25 11:29:35,967 studio.core          INFO       |   |   |   |   DataTableCsvReader.read - End with 0.1774s elapsed.
# 2020-06-25 11:29:35,967 studio.core          INFO       |   |   |   Read from 'bing_data_label.tsv' via DataTableTsvHandler - End with 0.1787s elapsed.
# 2020-06-25 11:29:35,967 studio.core          INFO       |   |   Handle input port "Dataset" - End with 0.3026s elapsed.
# 2020-06-25 11:29:35,967 studio.modulehost    INFO       |   |   Parse ColumnSelection parameter
# 2020-06-25 11:29:35,967 studio.modulehost    INFO       |   |   Parse bool parameter
# 2020-06-25 11:29:35,967 studio.core          INFO       |   Reflect input ports and parameters - End with 0.3031s elapsed.
# 2020-06-25 11:29:35,968 studio.core          INFO       |   RemoveDuplicateRowsModule.run - Start:
# 2020-06-25 11:29:35,968 studio.core          DEBUG      |   |   kwargs:
# 2020-06-25 11:29:35,968 studio.core          DEBUG      |   |   |   data_table = <azureml.studio.common.datatable.data_table.DataTable object at 0x7f991c036cc0>
# 2020-06-25 11:29:35,968 studio.core          DEBUG      |   |   |   key_columns = <azureml.studio.common.datatable.data_table.DataTableColumnSelection object at 0x7f9914286b70>
# 2020-06-25 11:29:35,968 studio.core          DEBUG      |   |   |   take_first_otherwise_last = True
# 2020-06-25 11:29:35,968 studio.core          DEBUG      |   |   validated_args:
# 2020-06-25 11:29:35,968 studio.core          DEBUG      |   |   |   data_table = <azureml.studio.common.datatable.data_table.DataTable object at 0x7f991c036cc0>
# 2020-06-25 11:29:35,968 studio.core          DEBUG      |   |   |   key_columns = <azureml.studio.common.datatable.data_table.DataTableColumnSelection object at 0x7f9914286b70>
# 2020-06-25 11:29:35,968 studio.core          DEBUG      |   |   |   take_first_otherwise_last = True
# 2020-06-25 11:29:35,969 studio.core          INFO       |   |   Remove duplicated rows - Start:
# 2020-06-25 11:29:35,973 studio.core          INFO       |   |   Remove duplicated rows - End with 0.0042s elapsed.
# 2020-06-25 11:29:35,974 studio.core          DEBUG      |   |   return:
# 2020-06-25 11:29:35,974 studio.core          DEBUG      |   |   |   [0] = <DataTable (793 Rows, 2 Cols) at 0x00007F98D53080B8>
# 2020-06-25 11:29:35,974 studio.core          INFO       |   RemoveDuplicateRowsModule.run - End with 0.0066s elapsed.
# 2020-06-25 11:29:35,974 studio.core          INFO       |   ModuleReflector._handle_output_ports - Start:
# 2020-06-25 11:29:35,975 studio.core          INFO       |   |   Handle output port "Results dataset" - Start:
# 2020-06-25 11:29:35,975 studio.modulehost    INFO       |   |   |   Data type: Dataset
# 2020-06-25 11:29:35,975 studio.modulehost    INFO       |   |   |   Create directory: '/mnt/batch/tasks/shared/LS_root/jobs/heta-eus/azureml/2317315d-4532-46b6-b989-de9707209a3a/mounts/workspaceblobstore/azureml/2317315d-4532-46b6-b989-de9707209a3a/Results_dataset'
# 2020-06-25 11:29:36,007 studio.core          INFO       |   |   |   Create file 'data.dataset.parquet' via DataTableDatasetHandler - Start:
# 2020-06-25 11:29:36,007 studio.modulehost    INFO       |   |   |   |   Write DataTable into Dataset
# 2020-06-25 11:29:36,007 studio.core          INFO       |   |   |   |   Write pickle file 'data.dataset' - Start:
# 2020-06-25 11:29:36,076 studio.core          INFO       |   |   |   |   Write pickle file 'data.dataset' - End with 0.0690s elapsed.
# 2020-06-25 11:29:36,077 studio.core          INFO       |   |   |   |   Write to parquet file 'data.dataset.parquet'. Rows: 793, Columns: 2. - Start:
# 2020-06-25 11:29:36,102 studio.core          INFO       |   |   |   |   Write to parquet file 'data.dataset.parquet'. Rows: 793, Columns: 2. - End with 0.0250s elapsed.
# 2020-06-25 11:29:36,102 studio.core          INFO       |   |   |   Create file 'data.dataset.parquet' via DataTableDatasetHandler - End with 0.0949s elapsed.
# 2020-06-25 11:29:36,102 studio.core          INFO       |   |   |   Create sidecar file 'data.schema' - Start:
# 2020-06-25 11:29:36,169 studio.core          INFO       |   |   |   Create sidecar file 'data.schema' - End with 0.0673s elapsed.
# 2020-06-25 11:29:36,170 studio.core          INFO       |   |   |   Create sidecar file 'data.visualization' - Start:
# 2020-06-25 11:29:36,230 studio.core          INFO       |   |   |   Create sidecar file 'data.visualization' - End with 0.0598s elapsed.
# 2020-06-25 11:29:36,230 studio.core          INFO       |   |   |   Create sidecar file 'data.metadata' - Start:
# 2020-06-25 11:29:36,297 studio.core          INFO       |   |   |   Create sidecar file 'data.metadata' - End with 0.0669s elapsed.
# 2020-06-25 11:29:36,539 studio.common        INFO       |   |   |   Writing meta successfully, datatype=DataTypes.DATASET
# 2020-06-25 11:29:36,539 studio.core          INFO       |   |   |   Create data type file 'data_type.json' - Start:
# 2020-06-25 11:29:36,607 studio.core          INFO       |   |   |   Create data type file 'data_type.json' - End with 0.0674s elapsed.
# 2020-06-25 11:29:36,607 studio.core          INFO       |   |   Handle output port "Results dataset" - End with 0.6322s elapsed.
# 2020-06-25 11:29:36,607 studio.core          INFO       |   ModuleReflector._handle_output_ports - End with 0.6325s elapsed.
# 2020-06-25 11:29:36,607 studio.core          INFO       |   ModuleStatistics.save_to_azureml - Start:
# Streaming azureml-logs/75_job_post-tvmps_a56482c300b240509ada69f6cfb808feb28e51b61dba1e1dc21739eef54f5503_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-06-25T11:29:41.018491
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (ruamel.yaml 0.15.89 (/azureml-envs/azureml_a62e52e5220d24c0f3e291434f99287c/lib/python3.6/site-packages), Requirement.parse('ruamel.yaml>0.16.7')).
# Starting job release. Current time:2020-06-25T11:29:41.933422
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 386
# Entering context manager injector. Current time:2020-06-25T11:29:41.947480
#
# StepRun(azureml://Remove Duplicate Rows) Execution Summary
# ===========================================================
# StepRun( azureml://Remove Duplicate Rows ) Status: Finalizing
# {'runId': '2317315d-4532-46b6-b989-de9707209a3a', 'target': 'aml-compute', 'status': 'Finalizing', 'startTimeUtc': '2020-06-25T11:29:07.120005Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '15db5008-6c13-4636-9e88-9dc17f6633b0', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '4ae6c832-f2eb-588f-a6a3-4af9dee9494b', 'azureml.pipelinerunid': 'e64b98e7-87cd-419b-b9f8-b03bb73b7c8e', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'afa83078-472d-434f-9834-6cd8f8f35363'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Dataset', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'urldecode_invoker.py', 'useAbsolutePath': False, 'arguments': ['python', '-m', 'azureml.studio.modulehost.module_invoker', '--module-name=azureml.studio.modules.datatransform.manipulation.remove_duplicate_rows.remove_duplicate_rows', '--dataset=$AZUREML_DATAREFERENCE_Dataset', '--results-dataset=$AZUREML_DATAREFERENCE_Results_dataset', '--key-column-selection-filter-expression=%7b%5c%22isFilter%5c%22%3atrue%2c%5c%22rules%5c%22%3a%5b%7b%5c%22exclude%5c%22%3afalse%2c%5c%22ruleType%5c%22%3a%5c%22ColumnNames%5c%22%2c%5c%22columns%5c%22%3a%5b%5c%22Id%5c%22%5d%7d%5d%7d', '--retain-first-duplicate-row=True'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-compute', 'dataReferences': {'Results_dataset': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/2317315d-4532-46b6-b989-de9707209a3a/Results_dataset', 'pathOnCompute': None, 'overwrite': True}}, 'data': {'Dataset': {'dataLocation': {'dataset': {'id': 'afa83078-472d-434f-9834-6cd8f8f35363', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'Dataset', 'pathOnCompute': None, 'overwrite': True}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment bing_data_bot_detection Environment', 'version': 'Autosave_2020-06-25T11:28:06Z_bd2fba2f', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['conda-forge'], 'dependencies': ['python=3.6.8', 'scikit-surprise=1.0.6', {'pip': ['azureml-designer-classic-modules==0.0.124', 'https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm', 'spacy==2.1.7']}], 'name': 'azureml_a62e52e5220d24c0f3e291434f99287c'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'AZUREML_PARAMETER_Key_column_selection_filter_expression': '{"isFilter":true,"rules":[{"exclude":false,"ruleType":"ColumnNames","columns":["Id"]}]}', 'AZUREML_PARAMETER_Retain_first_duplicate_row': 'True'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 0, 'parameterServerCount': 0}, 'mpi': {'processCountPerNode': 0}, 'hdi': {'yarnDeployMode': 'None'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '1g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}, 'cmAksCompute': {'c ...
# StepRunId: 6793c3fb-2712-44ac-b36c-6b5c7b7632e5
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bing_data_bot_detection/runs/6793c3fb-2712-44ac-b36c-6b5c7b7632e5?wsid=/subscriptions/e9b2ec51-5c94-4fa8-809a-dc1e695e4896/resourcegroups/thy-experiment/workspaces/heta-EUS
# StepRun( azureml://Join Data ) Status: NotStarted
# StepRun( azureml://Join Data ) Status: Queued
# StepRun( azureml://Join Data ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_a56482c300b240509ada69f6cfb808feb28e51b61dba1e1dc21739eef54f5503_d.txt
# ========================================================================================================================
# 2020-06-25T11:30:25Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2020-06-25T11:30:25Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# 2020-06-25T11:30:25Z Starting output-watcher...
# 2020-06-25T11:30:25Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_1b19c9f6d5dc5a4da4df9e1ba0ccb2d7
# Digest: sha256:d5173bb5fc75f022a73a7a0fda3561c5b05573048b7963c1e96343402f510417
# Status: Image is up to date for viennaglobal.azurecr.io/azureml/azureml_1b19c9f6d5dc5a4da4df9e1ba0ccb2d7:latest
# d623b6fccb2afbed7878eedca04c9d51bc88128a004678cf5755307965b81526
# 2020/06/25 11:30:27 Starting App Insight Logger for task:  containerSetup
# 2020/06/25 11:30:27 Version: 3.0.01255.0021 Branch: JobPrepRelaseCustomDebug Commit: 34b9fb48
# 2020/06/25 11:30:27 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/06/25 11:30:27 sshd inside container not required for job, skipping setup.
# ...
# StepRunId: 564c05c3-7580-4f44-b151-9f3de65eeddf
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bing_data_bot_detection/runs/564c05c3-7580-4f44-b151-9f3de65eeddf?wsid=/subscriptions/e9b2ec51-5c94-4fa8-809a-dc1e695e4896/resourcegroups/thy-experiment/workspaces/heta-EUS
# StepRun( TLC: Test ) Status: NotStarted
# StepRun( TLC: Test ) Status: Queued
# StepRun( TLC: Test ) Status: Running
#
# Streaming azureml-logs/65_job_prep-tvmps_6c862dcdf55fc702d9fdab02eb6f81796d806c272539e9545afe20f225dac1a7_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-06-25T11:38:08.321791
# Starting job preparation. Current time:2020-06-25T11:38:13.029414
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 089da66a-7f5c-441d-aab0-0a43f384bc1c
# Starting the daemon thread to refresh tokens in background for process with pid = 10120
# Starting project file download.
# Finished project file download.
# Entering job preparation. Current time:2020-06-25T11:38:28.387918
# Entering job preparation. Current time:2020-06-25T11:38:29.118910
# downloadDataStore - Download from datastores if requested.
# Entering context manager injector. Current time:2020-06-25T11:38:30.065740
# Starting the daemon thread to refresh tokens in background for process with pid = 2884
# downloadDataStore completed
# Job preparation is complete. Current time:2020-06-25T11:38:34.981367
#
# Streaming azureml-logs/70_mpi_log.txt
# =====================================
# 2020/06/25 11:38:43 Start to recover file system on master session
#
# Streaming azureml-logs/70_driver_log_0.txt
# ==========================================
# Entering context manager injector. Current time:2020-06-25T11:38:48.772315
# This is an MPI job. Rank:0
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (entrypoints 0.2.3 (c:\anaconda\lib\site-packages), Requirement.parse('entrypoints<0.4.0,>=0.3.0'), {'flake8'}).
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception module 'azureml' has no attribute 'dataprep'.
# Initialize DatasetContextManager.
# Starting the daemon thread to refresh tokens in background for process with pid = 10652
# Set Dataset Trained_Model's target path to D:\Users\YourUsername\AppData\Local\Temp\tmpglxci52c
# Set Dataset Test_Data's target path to D:\Users\YourUsername\AppData\Local\Temp\tmpn0iwfyue
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==0.1.0.16323496 azureml-dataprep==1.8.3a2020062301. Session id: 541570c7-56a6-4f4c-b6c5-35a6f13a06af.
# Processing 'Trained_Model'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'dataset/d4dc213b-f43a-4e9d-a789-631c3c65e6ff/Trained_Model/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "df552c5b-248b-48c2-aab4-4c0077a04146",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='heta-EUS', subscription_id='e9b2ec51-5c94-4fa8-809a-dc1e695e4896', resource_group='thy-experiment')"
#   }
# }
# Downloading Trained_Model to D:\Users\YourUsername\AppData\Local\Temp\tmpglxci52c
# Downloaded Trained_Model to D:\Users\YourUsername\AppData\Local\Temp\tmpglxci52c as folder.
# Processing 'Test_Data'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'azureml/6b18e3e3-99e6-4e16-a7fc-bce5e29b2937/Results_dataset2')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "dba08954-4a39-4725-82c2-8e95a7ca4a4d",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='heta-EUS', subscription_id='e9b2ec51-5c94-4fa8-809a-dc1e695e4896', resource_group='thy-experiment')"
#   }
# }
# Downloading Test_Data to D:\Users\YourUsername\AppData\Local\Temp\tmpn0iwfyue
# Downloaded Test_Data to D:\Users\YourUsername\AppData\Local\Temp\tmpn0iwfyue as folder.
# Processing 'Per_Instance_Predictions'.
# Exit __enter__ of DatasetContextManager
# Preparing to call script [ F:\/azureml/564c05c3-7580-4f44-b151-9f3de65eeddf/entry.py ] with arguments: ['--trained_model', '$Trained_Model', '--test_data', '$Test_Data', '--instances_reader', 'StreamingInstances', '--instances_settings', '{header+ label=0 name=1}', '--cache_instances_in_memory', '+', '--random_seed', '123', '--use_threads', '+', '--proportion_of_train_data_to_use', '1', '--print_model_summary', '+', '--per_instance_predictions', '$Per_Instance_Predictions']
# After variable expansion, calling script [ F:\/azureml/564c05c3-7580-4f44-b151-9f3de65eeddf/entry.py ] with arguments: ['--trained_model', 'D:\\Users\\YourUsername\\AppData\\Local\\Temp\\tmpglxci52c', '--test_data', 'D:\\Users\\YourUsername\\AppData\\Local\\Temp\\tmpn0iwfyue', '--instances_reader', 'StreamingInstances', '--instances_settings', '{header+ label=0 name=1}', '--cache_instances_in_memory', '+', '--random_seed', '123', '--use_threads', '+', '--proportion_of_train_data_to_use', '1', '--print_model_summary', '+', '--per_instance_predictions', 'D:\\Users\\YourUsername\\AppData\\Local\\Temp\\tmprztzsp90']
#
# TL.exe /c Test /m D:\Users\YourUsername\AppData\Local\Temp\tmpglxci52c\trained_model D:\Users\YourUsername\AppData\Local\Temp\tmpn0iwfyue\data.tsv /o D:\Users\YourUsername\AppData\Local\Temp\tmprztzsp90\per_instance_predictions  /inst StreamingInstances /instset {header+ label=0 name=1} /cacheInst+ /rs 123  /threads+ /tp 1.0      /summary+
# F:\azureml\564c05c3-7580-4f44-b151-9f3de65eeddf\TL.exe /c Test /m D:\Users\YourUsername\AppData\Local\Temp\tmpglxci52c\trained_model D:\Users\YourUsername\AppData\Local\Temp\tmpn0iwfyue\data.tsv /o D:\Users\YourUsername\AppData\Local\Temp\tmprztzsp90\per_instance_predictions  /inst StreamingInstances /instset {header+ label=0 name=1} /cacheInst+ /rs 123  /threads+ /tp 1.0      /summary+
# 6/25/2020 11:39:50 AM  **************** TESTING ****************
#
#
# ----------------------------------------------------------------------------------------
# TEST POSITIVE RATIO:	0.5949 (47/(47+32))
# TRAIN POSITIVE RATIO:	0.6317
#
# Confusion table:
#          ||===============================|
#          ||            PREDICTED          |
#   TRUTH  ||    positive    |   negative   | RECALL
#          ||===============================|
#  positive||   47           |    0         | 1.0000 (47/47)
#  negative||   1            |    31        | 0.9688 (31/32)
#          ||===============================|
#  PRECISION 0.9792 (47/48)    1.0000(31/31)
#
# OVERALL 0/1 ACCURACY:		0.9873 (78/79)
# LOG LOSS/instance:		0.04828577
# TEST-SET ENTROPY (prior LL/in):	0.97383548
# LOG-LOSS REDUCTION (RIG):	95.0417%
#    TRAIN-SET PRIOR LL/inst (train-test cross-entropy):			0.97796206
#    TRAIN-SET LL REDUCTION (trainRIG diagnostic, *not* for comparisons):	95.0626%
# AUC:				1.0000
#
#
# ----------------------------------------------------------------------------------------
#
# OVERALL RESULTS
# ---------------------------------------
# ACCURACY:            0.9873 (0.0000)
# POS. PRECISION:      0.9792 (0.0000)
# POS. RECALL:         1.0000 (0.0000)
# NEG. PRECISION:      1.0000 (0.0000)
# NEG. RECALL:         0.9688 (0.0000)
# LOG-LOSS:            0.0483 (0.0000)
# LOG-LOSS REDUCTION: 95.0417 (0.0000)
# AUC:                 1.0000 (0.0000)
#
# ---------------------------------------
# 6/25/2020 11:39:51 AM	 Time elapsed(s): 19.602
# Starting the daemon thread to refresh tokens in background for process with pid = 10652
#
#
# The experiment completed successfully. Finalizing run...
# Enter __exit__ of DatasetContextManager
# Uploading output 'Per_Instance_Predictions'.
# Exit __exit__ of DatasetContextManager
#
# Streaming azureml-logs/75_job_post-tvmps_6c862dcdf55fc702d9fdab02eb6f81796d806c272539e9545afe20f225dac1a7_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-06-25T11:40:03.759178
#
# StepRun(TLC: Test) Execution Summary
# =====================================
# StepRun( TLC: Test ) Status: Finalizing
# {'runId': '564c05c3-7580-4f44-b151-9f3de65eeddf', 'target': 'windows-cluster', 'status': 'Finalizing', 'startTimeUtc': '2020-06-25T11:37:37.611951Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '089da66a-7f5c-441d-aab0-0a43f384bc1c', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '36342066-4af0-4f95-9321-a6e67646fcf6', 'azureml.pipelinerunid': 'e64b98e7-87cd-419b-b9f8-b03bb73b7c8e', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'df552c5b-248b-48c2-aab4-4c0077a04146'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Trained_Model', 'mechanism': 'Download'}}, {'dataset': {'id': 'dba08954-4a39-4725-82c2-8e95a7ca4a4d'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Test_Data', 'mechanism': 'Download'}}], 'outputDatasets': [{'identifier': {'savedId': '591374e4-6e9d-4443-84ee-7fe2429478dd'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'Per_Instance_Predictions'}}], 'runDefinition': {'script': 'entry.py', 'useAbsolutePath': False, 'arguments': ['--trained_model', '$AZUREML_DATAREFERENCE_Trained_Model', '--test_data', '$AZUREML_DATAREFERENCE_Test_Data', '--instances_reader', '$AZUREML_PARAMETER_Instances_Reader', '--instances_settings', '$AZUREML_PARAMETER_Instances_Settings', '--cache_instances_in_memory', '$AZUREML_PARAMETER_Cache_Instances_In_Memory', '--random_seed', '$AZUREML_PARAMETER_Random_Seed', '--use_threads', '$AZUREML_PARAMETER_Use_Threads', '--proportion_of_train_data_to_use', '$AZUREML_PARAMETER_Proportion_Of_Train_Data_To_Use', '--print_model_summary', '$AZUREML_PARAMETER_Print_Model_Summary', '--per_instance_predictions', 'DatasetOutputConfig:Per_Instance_Predictions'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'Mpi', 'target': 'windows-cluster', 'dataReferences': {}, 'data': {'Trained_Model': {'dataLocation': {'dataset': {'id': 'df552c5b-248b-48c2-aab4-4c0077a04146', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Download', 'environmentVariableName': 'Trained_Model', 'pathOnCompute': None, 'overwrite': True}, 'Test_Data': {'dataLocation': {'dataset': {'id': 'dba08954-4a39-4725-82c2-8e95a7ca4a4d', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Download', 'environmentVariableName': 'Test_Data', 'pathOnCompute': None, 'overwrite': True}}, 'outputData': {'Per_Instance_Predictions': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}}, 'mechanism': 'Upload', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': True, 'sourceGlobs': {'globPatterns': None}}}}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment bing_data_bot_detection Environment', 'version': 'Autosave_2020-06-25T11:37:18Z_fe0d46ca', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['defaults'], 'dependencies': ['python=3.6.2', {'pip': ['--extra-index-url=https://azuremlsdktestpypi.azureedge.net/CLI-SDK-Runners-Validation/16312570', 'azureml-defaults==0.1.0.16312570', 'azureml-pipeline-wrapper==0.1.0.16312570']}], 'name': 'azureml_ffabf8df7897b7f964e2c223aedf0937'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'AZUREML_PARAMETER_Instances_Reader': 'StreamingInstances', 'AZUREML_PARAMETER_Instances_Settings': '{header+ label=0 name=1}', 'AZUREML_PARAMETER_Cache_Instances_In_Memory': '+', 'AZUREML_PARAMETER_Random_Seed': '123', 'AZUREML_PARAMETER_Use_Threads': '+', 'AZUREML_PARAMETER_Proportion_Of_Train_Data_To_Use': '1', 'AZUREML_PARAMETER_Skipchartrain': None, 'AZUREML_PARAMETER_Skipchartest': None, 'AZUREML_P ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Completed
# {'runId': 'e64b98e7-87cd-419b-b9f8-b03bb73b7c8e', 'status': 'Completed', 'startTimeUtc': '2020-06-25T11:27:52.108367Z', 'endTimeUtc': '2020-06-25T11:41:06.039051Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Designer', 'runType': 'HTTP', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://hetaeus3271596160.blob.core.windows.net/azureml/ExperimentRun/dcid.e64b98e7-87cd-419b-b9f8-b03bb73b7c8e/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=drBkjIQqezqk5%2FC77A%2FL0ItLdnW%2Bjh6wcbnI3gtY3rM%3D&st=2020-06-25T11%3A31%3A10Z&se=2020-06-25T19%3A41%3A10Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://hetaeus3271596160.blob.core.windows.net/azureml/ExperimentRun/dcid.e64b98e7-87cd-419b-b9f8-b03bb73b7c8e/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=QO2HAweKNdT%2Fr0TS7aqfurcL1PKyKY%2F8s0DjUENG39I%3D&st=2020-06-25T11%3A31%3A10Z&se=2020-06-25T19%3A41%3A10Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://hetaeus3271596160.blob.core.windows.net/azureml/ExperimentRun/dcid.e64b98e7-87cd-419b-b9f8-b03bb73b7c8e/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=JrxmO5UpW5S44FNQYbZiz0TyNstmKM2G74bY7fP0AsI%3D&st=2020-06-25T11%3A31%3A10Z&se=2020-06-25T19%3A41%3A10Z&sp=r'}}
# <RunStatus.completed: 'Completed'>
